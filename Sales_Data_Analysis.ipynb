# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('Sales data Tablue.xlsx')
df
# Out:
#                         Region               Country   Item_Type  \
# 0             Central America   Antigua and Barbuda    Baby Food
# 1             Central America                 Panama      Snacks
# 2                       Europe        Czech Republic   Beverages
# 3                         Asia           North Korea      Cereal
# 4                         Asia             Sri Lanka      Snacks
# ...                        ...                   ...         ...
# 4995         Australia/Oceania           New Zealand  Vegetables
# 4996  Middle East/North Africa            Azerbaijan      Snacks
# 4997                      Asia               Myanmar   Baby Food
# 4998                    Europe               Finland     Clothes
# 4999        Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority           Order_Date  Year   Order_ID  \
# 0           Online              M           12/20/2013  2013  957081544
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 547.0+ KB

# %%
df.describe()
# Out:
#               Year      Order_ID   Units_Sold  Unit_SellingPrice  \
# count  5000.000000  5.000000e+03  5000.000000        5000.000000
# mean   2013.318000  5.482709e+08  5030.926400         265.745564
# std       2.177665  2.595496e+08  2912.291375         218.716695
# min    2010.000000  1.342124e+07     2.000000           9.330000
# 25%    2011.000000  3.191029e+08  2456.250000          81.730000
# 50%    2013.000000  5.521214e+08  5122.000000         154.060000
# 75%    2015.000000  7.685650e+08  7574.500000         437.200000
# max    2017.000000  9.998797e+08  9999.000000         668.270000
#
#        Unit_MakingCost  unit_per Profit  Total profit
# count      5000.000000      5000.000000  5.000000e+03
# mean        187.494144        78.251420  3.925010e+05
# std         176.416280        53.403068  3.824200e+05
# min           6.920000         2.410000  1.687000e+01
# 25%          35.840000        25.060000  8.549190e+04
# 50%          97.440000        63.130000  2.796242e+05
# ...

# %%
df.isnull().sum()
# Out:
# Region               0
# Country              0
# Item_Type            0
# Sales_Channel        0
# Order_Priority       0
# Order_Date           0
# Year                 0
# Order_ID             0
# Ship_Date            0
# Units_Sold           0
# Unit_SellingPrice    0
# Unit_MakingCost      0
# unit_per Profit      0
# Total profit         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Region                  7
# Country               185
# Item_Type              12
# Sales_Channel           2
# Order_Priority          4
# Order_Date           2305
# Year                    8
# Order_ID             5000
# Ship_Date            2320
# Units_Sold           3948
# Unit_SellingPrice      12
# Unit_MakingCost        12
# unit_per Profit        12
# Total profit         4909
# dtype: int64

# %%
df['Total profit'].describe()
# Out:
# count    5.000000e+03
# mean     3.925010e+05
# std      3.824200e+05
# min      1.687000e+01
# 25%      8.549190e+04
# 50%      2.796242e+05
# 75%      5.649067e+05
# max      1.726007e+06
# Name: Total profit, dtype: float64

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
plt.boxplot(df['Total profit'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2951d26f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d2951d0dd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d2951d2750>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2951d0920>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d2951d2c00>],
#  'means': []}

# %%
plt.boxplot(df['Units_Sold'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d29523b0e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d295198920>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d29523b440>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2952391c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d295238dd0>],
#  'means': []}

# %%
plt.boxplot(df['Unit_SellingPrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2951ce4e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d2951ceae0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d2951ce300>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2951cefc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d2951cf2f0>],
#  'means': []}

# %%
plt.boxplot(df['Unit_MakingCost'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2950faa50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d2950b4d70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d295277830>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2950b64b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d29497a000>],
#  'means': []}

# %%
plt.boxplot(df['unit_per Profit'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d295023f20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d295020f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d295274830>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d295021190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d295021220>],
#  'means': []}

# %% [markdown]
# FIXING OUTLIERS

# %%
def Iqr(x):
    q1=x.quantile(.25)
    q3=x.quantile(.75)
    IQR=q3-q1
    Lf=q1-(1.5*IQR)
    Uf=q3+(1.5*IQR)
    print("Lf-->",Lf,"Uf-->",Uf)

# %%
Iqr(df['Total profit'])
# Out:
# Lf--> -633630.23625 Uf--> 1284028.79375

# %%
df['Total profit']=np.where(df['Total profit']>1284028.79375,1284028.79375,df['Total profit'])
plt.boxplot(df['Total profit'])
plt.show()

# %% [markdown]
# VALUE COUNTS

# %%
df['Total profit'].value_counts()
# Out:
# Total profit
# 1.284029e+06    197
# 3.352203e+05      2
# 8.477798e+04      2
# 5.225792e+05      2
# 2.921016e+05      2
#                ...
# 1.238380e+05      1
# 6.668980e+05      1
# 1.593733e+04      1
# 1.109106e+06      1
# 3.156500e+05      1
# Name: count, Length: 4718, dtype: int64

# %%
df['Unit_SellingPrice'].value_counts()
# Out:
# Unit_SellingPrice
# 47.45     447
# 9.33      447
# 255.28    445
# 437.20    424
# 668.27    424
# 651.21    420
# 81.73     415
# 154.06    410
# 421.89    399
# 152.58    398
# 109.28    386
# 205.70    385
# Name: count, dtype: int64

# %%
df['Units_Sold'].value_counts()
# Out:
# Units_Sold
# 2       5
# 5745    4
# 7153    4
# 531     4
# 7948    4
#        ..
# 2019    1
# 5096    1
# 3965    1
# 420     1
# 5000    1
# Name: count, Length: 3948, dtype: int64

# %%
df['Unit_MakingCost'].value_counts()
# Out:
# Unit_MakingCost
# 31.79     447
# 6.92      447
# 159.42    445
# 263.33    424
# 502.54    424
# 524.96    420
# 56.67     415
# 90.93     410
# 364.69    399
# 97.44     398
# 35.84     386
# 117.11    385
# Name: count, dtype: int64

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# San Marino                  40
# Andorra                     40
# Ghana                       38
# Mauritius                   38
# United States of America    38
# Tonga                       37
# South Korea                 36
# Haiti                       36
# Somalia                     36
# Grenada                     36
# Name: count, dtype: int64

# %% [markdown]
# VISUALIZATION

# %%
df['new_year']=df['Year'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
#  14  new_year           5000 non-null   object
# dtypes: float64(4), int64(3), object(8)
# ...

# %%
plt.bar(df['new_year'],df["Units_Sold"])
plt.show()

# %%
#df.groupby('categorical column')['numerical column'].sum() - it will group the values of the column which has different data into one.
df.groupby('new_year')['Units_Sold'].sum()
# Out:
# new_year
# 2010    3130137
# 2011    3351698
# 2012    3485045
# 2013    3359120
# 2014    3217492
# 2015    3500005
# 2016    3280818
# 2017    1830317
# Name: Units_Sold, dtype: int64

# %%
df.groupby('new_year')['Units_Sold'].sum().plot.bar(color='c')
plt.show()
'''The given bar chart shows the year wise units sold'''
# Out:
# 'The given bar chart shows the year wise units sold'

# %%
df.groupby("new_year")["Units_Sold"].count()
# Out:
# new_year
# 2010    632
# 2011    658
# 2012    678
# 2013    660
# 2014    660
# 2015    679
# 2016    670
# 2017    363
# Name: Units_Sold, dtype: int64

# %%
df['Total_cost']=df['Units_Sold']*df['Unit_MakingCost']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
#  14  new_year           5000 non-null   object
#  15  Total_cost         5000 non-null   float64
# ...

# %%
df.groupby('new_year')['Total_cost'].sum().plot.bar(color='m')
# Out:
# <Axes: xlabel='new_year'>

# %%
df.groupby("new_year")["Total_cost"].count()
# Out:
# new_year
# 2010    632
# 2011    658
# 2012    678
# 2013    660
# 2014    660
# 2015    679
# 2016    670
# 2017    363
# Name: Total_cost, dtype: int64

# %%
df["new_year"].value_counts()
# Out:
# new_year
# 2015    679
# 2012    678
# 2016    670
# 2013    660
# 2014    660
# 2011    658
# 2010    632
# 2017    363
# Name: count, dtype: int64

# %%
df[df["Year"]==2010]["Units_Sold"].sum()
# Out:
# 3130137

# %%
df['Item_Type'].unique()
# Out:
# array(['Baby Food', 'Snacks', 'Beverages', 'Cereal', 'Personal Care',
#        'Clothes', 'Office Supplies', 'Cosmetics', 'Meat', 'Fruits',
#        'Vegetables', 'Household'], dtype=object)

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Unit_SellingPrice'].mean())
plt.bar_label(plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Unit_SellingPrice'].mean()))
plt.xlabel("Item Type")
plt.ylabel("Unit Selling Price")
plt.title("Item type vs unit selling price ")
plt.show()

# %%
df['Region'].unique()
# Out:
# array(['Central America ', 'Europe', 'Asia', 'Middle East/North Africa',
#        'Australia/Oceania', 'Sub-Saharan Africa', 'North America'],
#       dtype=object)

# %%
df.groupby('Region')['Total profit'].mean()
# Out:
# Region
# Asia                        378695.808983
# Australia/Oceania           408781.353170
# Central America             377231.600761
# Europe                      369715.185728
# Middle East/North Africa    371953.763969
# North America               373398.984458
# Sub-Saharan Africa          403666.585146
# Name: Total profit, dtype: float64

# %%
x=df.groupby("Country")['Total profit'].sum().head(5)
x
# Out:
# Country
# Afghanistan    6.010732e+06
# Albania        9.724111e+06
# Algeria        7.453133e+06
# Andorra        1.486097e+07
# Angola         7.448354e+06
# Name: Total profit, dtype: float64

# %%
plt.bar(x.index,x)
plt.bar_label(plt.bar(x.index,x))
plt.title("Total profit of first 5 countries")
plt.xlabel("Country")
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# TOTAL PROFIT

# %% [markdown]
# 1. REGION VS TOTAL PROFIT

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Region'].unique(),df.groupby('Region')['Total profit'].mean(),color = "violet")
plt.bar_label(plt.bar(df['Region'].unique(),df.groupby('Region')['Total profit'].mean(),color = "violet"))
plt.title("Region wise Total profit")
plt.xlabel("Regions")
plt.ylabel("Total profit")
plt.show()

# %% [markdown]
# 2. COUNTRY(FIRST FIVE) VS TOTAL PROFIT

# %%
x=df.groupby("Country")['Total profit'].sum().head(5)
plt.bar(x.index,x,color='blue')
plt.bar_label(plt.bar(x.index,x,color='blue'))
plt.xlabel("Country")
plt.ylabel("Total Profit")
plt.title("Total profit of Top five countries")
# Out:
# Text(0.5, 1.0, 'Total profit of Top five countries')

# %% [markdown]
# 3. COUNTRY(LAST FIVE) VS TOTAL PROFIT

# %%
x=df.groupby("Country")['Total profit'].sum().tail(5)
plt.bar(x.index,x)
plt.bar_label(plt.bar(x.index,x))
plt.xlabel("Country")
plt.ylabel("Total Profit")
plt.title("Total profit of Bottom five countries")
# Out:
# Text(0.5, 1.0, 'Total profit of Bottom five countries')

# %% [markdown]
# 4. ITEM_TYPE VS TOTAL PROFIT

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Total profit'].mean(),color='aqua')
plt.bar_label(plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Total profit'].mean(),color='aqua'))
plt.xlabel("Item Type")
plt.ylabel("Total Profit")
plt.title("Item type vs Total Profit ")
plt.show()

# %% [markdown]
# 5. YEAR VS TOTAL PROFIT

# %%
plt.figure(figsize=(15,5))
plt.bar(df['new_year'].unique(),df.groupby('new_year')['Total profit'].mean(),color = "violet")
plt.bar_label(plt.bar(df['new_year'].unique(),df.groupby('new_year')['Total profit'].mean(),color = "violet"))
plt.title("Year wise Total profit")
plt.xlabel("Year")
plt.ylabel("Total profit")
plt.show()

# %% [markdown]
# TOTAL COST

# %% [markdown]
# 1. REGION VS TOTAL COST

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Region'].unique(),df.groupby('Region')['Total_cost'].mean(),color = "maroon")
plt.bar_label(plt.bar(df['Region'].unique(),df.groupby('Region')['Total_cost'].mean(),color = "maroon"))
plt.title("Region wise Total cost")
plt.xlabel("Regions")
plt.ylabel("Total cost")
plt.show()

# %% [markdown]
# 2. COUNTRY VS TOTAL COST

# %%
x=df.groupby("Country")['Total_cost'].sum().head(5)
plt.bar(x.index,x,color='lightcoral')
plt.bar_label(plt.bar(x.index,x,color='lightcoral'))
plt.xlabel("Country")
plt.ylabel("Total cost")
plt.title("Total cost of Top five countries")
plt.show()

# %% [markdown]
# 3. ITEM TYPE VS TOTAL COST

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Total_cost'].mean(),color='skyblue')
plt.bar_label(plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Total_cost'].mean(),color='skyblue'))
plt.xlabel("Item Type")
plt.ylabel("Total cost")
plt.title("Item type vs Total cost ")
plt.show()

# %% [markdown]
# 4. YEAR WISE TOTAL COST

# %%
plt.figure(figsize=(15,5))
plt.bar(df['new_year'].unique(),df.groupby('new_year')['Total_cost'].mean(),color = "pink")
plt.bar_label(plt.bar(df['new_year'].unique(),df.groupby('new_year')['Total_cost'].mean(),color = "pink"))
plt.title("Year wise Total cost")
plt.xlabel("Year")
plt.ylabel("Total cost")
plt.show()

# %% [markdown]
# TOTAL SALES

# %%
df['Total_Sales']=df['Unit_SellingPrice']*df['Units_Sold']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
#  14  new_year           5000 non-null   object
#  15  Total_cost         5000 non-null   float64
# ...

# %% [markdown]
# 1. REGION WISE TOTAL SALES

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Region'].unique(),df.groupby('Region')['Total_Sales'].sum(),color = "orchid")
plt.bar_label(plt.bar(df['Region'].unique(),df.groupby('Region')['Total_Sales'].sum(),color = "orchid"))
plt.title("Region wise Total Sales")
plt.xlabel("Regions")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# 2. COUNTRY WISE TOTAL SALES

# %%
x=df.groupby("Country")['Total_Sales'].sum().head(5)
plt.bar(x.index,x,color='plum')
plt.bar_label(plt.bar(x.index,x,color='plum'))
plt.xlabel("Country")
plt.ylabel("Total Sales")
plt.title("Total Sale of Top five countries")
plt.show()

# %% [markdown]
# 3. ITEM TYPE VS TOTAL SALES

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Total_Sales'].sum(),color='indigo')
plt.bar_label(plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Total_Sales'].sum(),color='indigo'))
plt.xlabel("Item Type")
plt.ylabel("Total Sales")
plt.title("Total Sale of different Items ")
plt.show()

# %% [markdown]
# 4. YEAR WISE TOTAL SALES

# %%
plt.figure(figsize=(15,5))
plt.bar(df['new_year'].unique(),df.groupby('new_year')['Total_Sales'].sum(),color = "slategrey")
plt.bar_label(plt.bar(df['new_year'].unique(),df.groupby('new_year')['Total_Sales'].sum(),color = "slategrey"))
plt.title("Year wise Total Sales")
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# UNITS SOLD

# %% [markdown]
# 1. REGION WISE UNITS SOLD

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Region'].unique(),df.groupby('Region')['Units_Sold'].mean(),color = "turquoise")
plt.bar_label(plt.bar(df['Region'].unique(),df.groupby('Region')['Units_Sold'].mean(),color = "turquoise"))
plt.title("Region wise Units sold")
plt.xlabel("Regions")
plt.ylabel("Units Sold")
plt.show()

# %% [markdown]
# 2. COUNTRY WISE UNITS SOLD

# %%
x=df.groupby("Country")['Units_Sold'].sum().head(5)
plt.bar(x.index,x,color='salmon')
plt.bar_label(plt.bar(x.index,x,color='salmon'))
plt.xlabel("Country")
plt.ylabel("Units Sold")
plt.title("Country Wise units sold")
plt.show()

# %% [markdown]
# 3. UNITS SOLD OF DIFFERENT ITEMS

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Units_Sold'].median(),color='skyblue')
plt.bar_label(plt.bar(df['Item_Type'].unique(),df.groupby('Item_Type')['Units_Sold'].median(),color='skyblue'))
plt.xlabel("Item Type")
plt.ylabel("Units Sold")
plt.title("Units sold of different items")
plt.show()

# %% [markdown]
# 4. YEAR WISE UNITS SOLD

# %%
plt.figure(figsize=(15,5))
plt.bar(df['new_year'].unique(),df.groupby('new_year')['Units_Sold'].mean(),color = "springgreen")
plt.bar_label(plt.bar(df['new_year'].unique(),df.groupby('new_year')['Units_Sold'].mean(),color = "springgreen"))
plt.title("Year wise Units sold")
plt.xlabel("Year")
plt.ylabel("Units sold")
plt.show()
